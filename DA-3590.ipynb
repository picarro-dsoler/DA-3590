# %%
import sqlite3
import pandas as pd
import os

# This will work in notebooks/Jupyter (where __file__ is not defined) by using the current working directory
#db_path = os.path.join(
#    os.getcwd(),
#    "eu-migration", "italgas_g2g_leak_data_ingester", "database", "italgas_g2g.db"
#)

db_path = "eu-migration/italga_g2g.db"

if not os.path.exists(db_path):
    raise FileNotFoundError(f"Database file not found at: {db_path}")

# Get the names of all tables in the database
with sqlite3.connect(db_path) as con:
    tables_df = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table';", con)
    table_names = tables_df['name'].tolist()

    print("Tables in database:", table_names)

with sqlite3.connect(db_path) as con:
    # Get the names of all tables in the database
    tables_df = pd.read_sql_query("SELECT * FROM Leaks", con)
tables_df.columns
# Out:
# Tables in database: []
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/personal-repos/.venv/lib/python3.9/site-packages/pandas/io/sql.py:2202, in SQLiteDatabase.execute(self, sql, params)
#    2201 try:
# -> 2202     cur.execute(sql, *args)
#    2203     return cur
#
# OperationalError: no such table: Leaks
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[1], line 25
#      21     print("Tables in database:", table_names)
#      23 with sqlite3.connect(db_path) as con:
#      24     # Get the names of all tables in the database
# ---> 25     tables_df = pd.read_sql_query("SELECT * FROM Leaks", con)
#      26 tables_df.columns
#
# ...
